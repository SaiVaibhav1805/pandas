# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Employee_Dataset.csv")
data
# Out:
#     employee_id department     designation  age  salary joining_date  \
# 0       EMP1000         IT  Senior Analyst   60   85000      invalid
# 1         emp_1         IT         Analyst  NaN   55000   10/06/2020
# 2       EMP1002      Sales             NaN   28   85000          NaN
# 3       EMP1003        it          Analyst   45   35000      invalid
# 4           NaN         IT             mgr  150   85000          NaN
# ..          ...        ...             ...  ...     ...          ...
# 995     EMP1995    Finance             NaN   60   55000   2019-05-10
# 996     EMP1996         IT         Analyst   35  250000      invalid
# 997     EMP1997      Sales  Senior Analyst  150  250000   2021/07/15
# 998     emp_998    Finance             NaN   60   85000   2019-05-10
# 999     EMP1999        it          Manager  150  ₹75000      invalid
#
#     last_promotion_date experience_years performance_rating is_active
# ...

# %% [markdown]
# ## TASK 1

# %%
data["joining_date"]=pd.to_datetime(data["joining_date"],errors="coerce")
k=data["joining_date"].isna().sum()
k
# Out:
# C:\Users\N.SAI VAIBHAV\AppData\Local\Temp\ipykernel_12184\1947650244.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["joining_date"]=pd.to_datetime(data["joining_date"],errors="coerce")
# np.int64(377)

# %% [markdown]
# ## TASK 2

# %%
data["employee_id"]=data["employee_id"].astype(str)
data["employee_id"]=data["employee_id"].str.strip()
data["employee_id"]=data["employee_id"].str.upper()

# %%
data["employee_id"]=data["employee_id"].str.replace(" ","",regex=False)
data["employee_id"]=data["employee_id"].str.replace("_","",regex=False)

# %%
data["employee_id"]
# Out:
# 0      EMP1000
# 1         EMP1
# 2      EMP1002
# 3      EMP1003
# 4          NAN
#         ...
# 995    EMP1995
# 996    EMP1996
# 997    EMP1997
# 998     EMP998
# 999    EMP1999
# Name: employee_id, Length: 1000, dtype: object

# %%
dup=data["employee_id"].duplicated().sum()
dup
# Out:
# np.int64(503)

# %%
data
# Out:
#     employee_id department     designation  age  salary joining_date  \
# 0       EMP1000         IT  Senior Analyst   60   85000          NaT
# 1          EMP1         IT         Analyst  NaN   55000   2020-10-06
# 2       EMP1002      Sales             NaN   28   85000          NaT
# 3       EMP1003        it          Analyst   45   35000          NaT
# 4           NAN         IT             mgr  150   85000          NaT
# ..          ...        ...             ...  ...     ...          ...
# 995     EMP1995    Finance             NaN   60   55000   2019-05-10
# 996     EMP1996         IT         Analyst   35  250000          NaT
# 997     EMP1997      Sales  Senior Analyst  150  250000   2021-07-15
# 998      EMP998    Finance             NaN   60   85000   2019-05-10
# 999     EMP1999        it          Manager  150  ₹75000          NaT
#
#     last_promotion_date experience_years performance_rating is_active
# ...

# %% [markdown]
# ## TASK 3

# %%
data["department"]=data["department"].str.strip()
data["department"]=data["department"].str.upper()

# %%
data["department"].tail(100)
# Out:
# 900         IT
# 901         HR
# 902         IT
# 903      SALES
# 904         IT
#         ...
# 995    FINANCE
# 996         IT
# 997      SALES
# 998    FINANCE
# 999         IT
# Name: department, Length: 100, dtype: object

# %%
data["salary"] = data["salary"].str.replace("₹", "", regex=False)
data["salary"] = data["salary"].str.replace(",", "", regex=False)
data["salary"] = pd.to_numeric(data["salary"], errors="coerce")

# %%
data["salary"]
# Out:
# 0       85000.0
# 1       55000.0
# 2       85000.0
# 3       35000.0
# 4       85000.0
#          ...
# 995     55000.0
# 996    250000.0
# 997    250000.0
# 998     85000.0
# 999     75000.0
# Name: salary, Length: 1000, dtype: float64

# %%
data
# Out:
#     employee_id department     designation  age    salary joining_date  \
# 0       EMP1000         IT  Senior Analyst   60   85000.0          NaT
# 1          EMP1         IT         Analyst  NaN   55000.0   2020-10-06
# 2       EMP1002      SALES             NaN   28   85000.0          NaT
# 3       EMP1003         IT         Analyst   45   35000.0          NaT
# 4           NAN         IT             mgr  150   85000.0          NaT
# ..          ...        ...             ...  ...       ...          ...
# 995     EMP1995    FINANCE             NaN   60   55000.0   2019-05-10
# 996     EMP1996         IT         Analyst   35  250000.0          NaT
# 997     EMP1997      SALES  Senior Analyst  150  250000.0   2021-07-15
# 998      EMP998    FINANCE             NaN   60   85000.0   2019-05-10
# 999     EMP1999         IT         Manager  150   75000.0          NaT
#
#     last_promotion_date experience_years performance_rating is_active
# ...

# %%
avg_sal=data.groupby("department")["salary"].mean()
avg_sal
# Out:
# department
# FINANCE    107397.959184
# HR         110117.647059
# IT         103373.205742
# SALES      110842.696629
# Name: salary, dtype: float64

# %% [markdown]
# ## TASK 4

# %%
data["age"]=pd.to_numeric(data["age"], errors="coerce")
data[(data["salary"].notna()) & (data["age"].isna())]
# Out:
#     employee_id department designation  age    salary joining_date  \
# 1          EMP1         IT     Analyst  NaN   55000.0   2020-10-06
# 5           NAN         IT         mgr  NaN   75000.0   2019-05-10
# 30      EMP1030         HR     Manager  NaN   85000.0   2019-05-10
# 31          NAN         HR     Analyst  NaN   55000.0   2020-10-06
# 38        EMP38         IT     Manager  NaN   35000.0   2021-07-15
# ..          ...        ...         ...  ...       ...          ...
# 959         NAN         HR         NaN  NaN  120000.0   2020-10-06
# 974      EMP974        NaN         mgr  NaN   85000.0   2021-07-15
# 976     EMP1976         HR     Analyst  NaN  250000.0   2019-05-10
# 982         NAN         HR         NaN  NaN   55000.0   2020-10-06
# 991         NAN         IT     Analyst  NaN  120000.0   2020-10-06
#
#     last_promotion_date experience_years performance_rating is_active
# 1               invalid                5                  3      True
# ...

# %% [markdown]
# ## TASK 6

# %%
data["performance_rating"]=pd.to_numeric(data["performance_rating"], errors="coerce")

# %%
data.groupby("designation")["performance_rating"].median()
# Out:
# designation
# ANALYST           3.0
# Analyst           3.0
# Manager           3.0
# Senior Analyst    3.0
# mgr               3.0
# Name: performance_rating, dtype: float64

# %% [markdown]
# ## TASK 7

# %%
data["last_promotion_date"]=pd.to_datetime(data["last_promotion_date"],errors="coerce")
data[data["last_promotion_date"]<data["joining_date"]]

#I have error here remember
# Out:
#     employee_id department     designation    age    salary joining_date  \
# 24      EMP1024    FINANCE             mgr   35.0   85000.0   2021-07-15
# 40        EMP40        NaN             NaN   60.0   85000.0   2021-07-15
# 44        EMP44      SALES             mgr   45.0   75000.0   2021-07-15
# 47          NAN    FINANCE         Analyst    NaN  250000.0   2021-07-15
# 71        EMP71      SALES         Manager   60.0  250000.0   2021-07-15
# 82        EMP82      SALES  Senior Analyst  150.0       NaN   2021-07-15
# 85          NAN      SALES             NaN   60.0   55000.0   2021-07-15
# 124         NAN      SALES         Analyst    NaN  250000.0   2021-07-15
# 138      EMP138    FINANCE             mgr   45.0  250000.0   2021-07-15
# 169      EMP169         IT             mgr   60.0  120000.0   2021-07-15
# 187         NAN        NaN         ANALYST  150.0  250000.0   2021-07-15
# 191     EMP1191      SALES             mgr    NaN       NaN   2021-07-15
# ...

# %%
data["last_promotion_date"].tail(100)
# Out:
# 900          NaT
# 901   2021-01-04
# 902          NaT
# 903          NaT
# 904   2021-01-04
#          ...
# 995          NaT
# 996          NaT
# 997          NaT
# 998          NaT
# 999          NaT
# Name: last_promotion_date, Length: 100, dtype: datetime64[ns]

# %% [markdown]
# ## TASK 8

# %%
data["experience_years"]=pd.to_numeric(data["experience_years"], errors="coerce")
data.loc[data["experience_years"] < 0, "experience_years"] = np.nan
data["experience_years"]
# Out:
# 0       5.0
# 1       5.0
# 2       3.0
# 3       1.0
# 4      12.0
#        ...
# 995     1.0
# 996     NaN
# 997     3.0
# 998    12.0
# 999     NaN
# Name: experience_years, Length: 1000, dtype: float64

# %%
data.loc[data["experience_years"]>data["age"], "experience_years"]
# Out:
# 10      8.0
# 17      3.0
# 43      1.0
# 49      5.0
# 56      8.0
#        ...
# 945     3.0
# 949     5.0
# 965    12.0
# 990    12.0
# 994    12.0
# Name: experience_years, Length: 90, dtype: float64

# %% [markdown]
# ## TASK 9

# %%
data
# Out:
#     employee_id department     designation    age    salary joining_date  \
# 0       EMP1000         IT  Senior Analyst   60.0   85000.0          NaT
# 1          EMP1         IT         Analyst    NaN   55000.0   2020-10-06
# 2       EMP1002      SALES             NaN   28.0   85000.0          NaT
# 3       EMP1003         IT         Analyst   45.0   35000.0          NaT
# 4           NAN         IT             mgr  150.0   85000.0          NaT
# ..          ...        ...             ...    ...       ...          ...
# 995     EMP1995    FINANCE             NaN   60.0   55000.0   2019-05-10
# 996     EMP1996         IT         Analyst   35.0  250000.0          NaT
# 997     EMP1997      SALES  Senior Analyst  150.0  250000.0   2021-07-15
# 998      EMP998    FINANCE             NaN   60.0   85000.0   2019-05-10
# 999     EMP1999         IT         Manager  150.0   75000.0          NaT
#
#     last_promotion_date  experience_years  performance_rating is_active
# ...

# %%
data["designation"]=data["designation"].str.strip()
data["designation"]=data["designation"].str.upper()

# %%
data["designation"] = data["designation"].str.replace(".", "", regex=False)
data["designation"] = data["designation"].str.replace("/", "", regex=False)

# %%
mapping = {
    "MGR": "MANAGER",
    "SR MANAGER": "MANAGER",
    "SENIOR MANAGER": "MANAGER",
    "SOFTWARE ENG": "SOFTWARE ENGINEER",
    "SW ENGINEER": "SOFTWARE ENGINEER",
    "S/W ENGINEER": "SOFTWARE ENGINEER",
    "DEV": "DEVELOPER",
    "PROGRAMMER": "DEVELOPER"
}

data["designation"] = data["designation"].replace(mapping)

# %%
mapp={"yes":"TRUE","no":"FALSE","true":"TRUE","false":"FALSE"}
data["is_active"]=data["is_active"].str.strip().str.lower().replace(mapp)

# %%
data["is_active"]
# Out:
# 0       NaN
# 1      TRUE
# 2       NaN
# 3       NaN
# 4      TRUE
#        ...
# 995    TRUE
# 996     NaN
# 997    TRUE
# 998    TRUE
# 999    TRUE
# Name: is_active, Length: 1000, dtype: object

# %%
active=data["is_active"].value_counts()
active
# Out:
# is_active
# TRUE     422
# FALSE    374
# Name: count, dtype: int64

# %%
data.groupby("department")["is_active"].apply(lambda x: x[x == "TRUE"].count())
# Out:
# department
# FINANCE     58
# HR          99
# IT         113
# SALES       96
# Name: is_active, dtype: int64

# %% [markdown]
# ## TASK 10

# %%
data["is_active"] = data["is_active"].map({
    "TRUE": True,
    "FALSE": False,
    "YES": True,
    "NO": False,
    "Y": True,
    "N": False,
    "1": True,
    "0": False,
    "ACTIVE": True,
    "INACTIVE": False
})

# %%
data["is_active"].tail(100)
# Out:
# 900    False
# 901      NaN
# 902      NaN
# 903    False
# 904    False
#        ...
# 995     True
# 996      NaN
# 997     True
# 998     True
# 999     True
# Name: is_active, Length: 100, dtype: object

# %%
data["is_active"] = data["is_active"].astype("boolean")

# %%
data["is_active"].dtype
# Out:
# BooleanDtype

# %% [markdown]
# ## TASK 11

# %%
data["joining_date"] = pd.to_datetime(
    data["joining_date"],
    dayfirst=True,
    errors="coerce"
)

# %%
today = pd.Timestamp.today()

data["tenure_years"] = (today - data["joining_date"]).dt.days / 365

# %%
data["tenure_years"]
# Out:
# 0           NaN
# 1      5.350685
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 995    6.761644
# 996         NaN
# 997    4.578082
# 998    6.761644
# 999         NaN
# Name: tenure_years, Length: 1000, dtype: float64

# %% [markdown]
# ## TASK 12

# %%
dept_salary_issue = data.groupby("department")["salary"].mean() * 100
dept_salary_issue
# Out:
# department
# FINANCE    1.073980e+07
# HR         1.101176e+07
# IT         1.033732e+07
# SALES      1.108427e+07
# Name: salary, dtype: float64

# %%
problem_dept = dept_salary_issue[dept_salary_issue > 25]
problem_dept
# Out:
# department
# FINANCE    1.073980e+07
# HR         1.101176e+07
# IT         1.033732e+07
# SALES      1.108427e+07
# Name: salary, dtype: float64

# %% [markdown]
# ## TASK 13

# %%
median_salary = data["salary"].median()
median_salary
# Out:
# 85000.0

# %%
data["underpaid_high_performer"] = (
    (data["performance_rating"] >= 4) &
    (data["salary"] < median_salary)
)
data[data["underpaid_high_performer"]]
# Out:
#     employee_id department     designation    age   salary joining_date  \
# 21          NAN         HR  SENIOR ANALYST   45.0  55000.0          NaT
# 26          NAN    FINANCE  SENIOR ANALYST   28.0  75000.0   2019-05-10
# 29          NAN    FINANCE         MANAGER   28.0  55000.0   2019-05-10
# 31          NAN         HR         ANALYST    NaN  55000.0   2020-10-06
# 60          NAN      SALES  SENIOR ANALYST   45.0  75000.0          NaT
# ..          ...        ...             ...    ...      ...          ...
# 946         NAN         IT  SENIOR ANALYST   45.0  35000.0   2019-05-10
# 964         NAN         IT         ANALYST   45.0  55000.0   2021-07-15
# 988     EMP1988    FINANCE         ANALYST   35.0  55000.0          NaT
# 995     EMP1995    FINANCE             NaN   60.0  55000.0   2019-05-10
# 999     EMP1999         IT         MANAGER  150.0  75000.0          NaT
#
#     last_promotion_date  experience_years  performance_rating  is_active  \
# ...

# %% [markdown]
# ## TASK 14

# %%
data["experience_years"] = pd.to_numeric(data["experience_years"], errors="coerce")

# %%
no_promo_5yrs = data[
    (data["last_promotion_date"].isna()) &
    (data["experience_years"] > 5)
]

# %%
data["missing_promotion_record"] = (
    (data["last_promotion_date"].isna()) &
    (data["experience_years"] > 5)
)
data["missing_promotion_record"]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: missing_promotion_record, Length: 1000, dtype: bool

# %% [markdown]
# ## TASK 15
