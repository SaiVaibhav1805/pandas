# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Dataset_1.csv")
df
# Out:
#     order_id customer_id  customer_age order_amount  order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5  2023-01-15   Debit Card
# 1    ORD1001         NaN          18.0         1200  2023/03/10   Debit Card
# 2    ORD1002       CUST2          35.0          NaN         NaN          NaN
# 3    ORD1003      user_3          35.0         1200  2023-01-15         Cash
# 4    ORD1004      user_4          -3.0      3500.75  2023-01-15         CARD
# ..       ...         ...           ...          ...         ...          ...
# 995      NaN    user_995          -3.0      3500.75  15/02/2023          upi
# 996      NaN     CUST996          18.0          NaN  2023-01-15  Credit Card
# 997      NaN    user_997          50.0          NaN  2023/03/10         Cash
# 998  ORD1998         NaN          65.0         1200  2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN  15/02/2023   Debit Card
#
#           city delivery_days is_delivered
# ...

# %% [markdown]
# ## TASK 1 --> identify all rows where order_amount is nonnumeric

# %%
non_numeric_rows = df[(df['order_amount'].isna()) & ((df['is_delivered']=='yes')|(df['is_delivered']=='True'))]
non_numeric_rows
# Out:
#     order_id customer_id  customer_age order_amount  order_date payment_mode  \
# 2    ORD1002       CUST2          35.0          NaN         NaN          NaN
# 14   ORD1014      CUST14          25.0          NaN  2023/03/10          upi
# 17       NaN         NaN          -3.0          NaN  15/02/2023          upi
# 29       NaN     user_29           NaN          NaN         NaN   Debit Card
# 38       NaN      CUST38          35.0          NaN  15/02/2023         CARD
# ..       ...         ...           ...          ...         ...          ...
# 970  ORD1970         NaN          18.0          NaN         NaN         Cash
# 982      NaN     CUST982          25.0          NaN  15/02/2023          NaN
# 987      NaN     CUST987          50.0          NaN  2023/03/10          NaN
# 996      NaN     CUST996          18.0          NaN  2023-01-15  Credit Card
# 999      NaN    user_999         120.0          NaN  15/02/2023   Debit Card
#
#           city delivery_days is_delivered
# ...

# %%
non_numeric=pd.to_numeric(df['order_amount'],errors='coerce')
non_numeric
df.head(50)
# Out:
#    order_id customer_id  customer_age order_amount  order_date payment_mode  \
# 0   ORD1000         NaN           NaN        250.5  2023-01-15   Debit Card
# 1   ORD1001         NaN          18.0         1200  2023/03/10   Debit Card
# 2   ORD1002       CUST2          35.0          NaN         NaN          NaN
# 3   ORD1003      user_3          35.0         1200  2023-01-15         Cash
# 4   ORD1004      user_4          -3.0      3500.75  2023-01-15         CARD
# 5       NaN         NaN           NaN         1200  2023-01-15         CARD
# 6   ORD1006       CUST6          -3.0          NaN         NaN          upi
# 7   ORD1007         NaN         120.0          NaN  2023-01-15         CARD
# 8   ORD1008      user_8          18.0          NaN  2023/03/10   Debit Card
# 9       NaN      user_9           NaN          NaN  2023/03/10          UPI
# 10      NaN         NaN          65.0         ₹999  2023-01-15  Credit Card
# ...

# %%
rep={'yes':'True','True':'True','No':'False','False':'False'}
df['is_delivered']=df['is_delivered'].replace(rep)
df['is_delivered']
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996     True
# 997      NaN
# 998    False
# 999     True
# Name: is_delivered, Length: 1000, dtype: object

# %%
df
# Out:
#     order_id customer_id  customer_age order_amount  order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5  2023-01-15   Debit Card
# 1    ORD1001         NaN          18.0         1200  2023/03/10   Debit Card
# 2    ORD1002       CUST2          35.0          NaN         NaN          NaN
# 3    ORD1003      user_3          35.0         1200  2023-01-15         Cash
# 4    ORD1004      user_4          -3.0      3500.75  2023-01-15         CARD
# ..       ...         ...           ...          ...         ...          ...
# 995      NaN    user_995          -3.0      3500.75  15/02/2023          upi
# 996      NaN     CUST996          18.0          NaN  2023-01-15  Credit Card
# 997      NaN    user_997          50.0          NaN  2023/03/10         Cash
# 998  ORD1998         NaN          65.0         1200  2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN  15/02/2023   Debit Card
#
#           city delivery_days is_delivered
# ...

# %%
for i in df:
    if(df['order_amount'].isnull()) and ((df['is_delivered']=='True')):
        df['is_delivered']=df['is_delivered'].replace({'True':'False','False':'False'})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21396\1528634857.py in ?()
#       1 for i in df:
# ----> 2     if(df['order_amount'].isnull()) and ((df['is_delivered']=='True')):
#       3         df['is_delivered']=df['is_delivered'].replace({'True':'False','False':'False'})
#       4 df
#
# c:\Users\N.SAI VAIBHAV\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ## TASK 2 -->Convert order_date to datetime and find orders where delivery days is negative after valid date conversion

# %%
df['order_date']=pd.to_datetime(df['order_date'],errors='coerce',format='%Y-%m-%d',dayfirst=True)
df
# Out:
#     order_id customer_id  customer_age order_amount order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5 2023-01-15   Debit Card
# 1    ORD1001         NaN          18.0         1200        NaT   Debit Card
# 2    ORD1002       CUST2          35.0          NaN        NaT          NaN
# 3    ORD1003      user_3          35.0         1200 2023-01-15         Cash
# 4    ORD1004      user_4          -3.0      3500.75 2023-01-15         CARD
# ..       ...         ...           ...          ...        ...          ...
# 995      NaN    user_995          -3.0      3500.75        NaT          upi
# 996      NaN     CUST996          18.0          NaN 2023-01-15  Credit Card
# 997      NaN    user_997          50.0          NaN        NaT         Cash
# 998  ORD1998         NaN          65.0         1200 2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN        NaT   Debit Card
#
#           city delivery_days is_delivered
# ...

# %%
rep1={'Three':3,'three':3}
df['delivery_days']=df['delivery_days'].replace(rep1)
df['delivery_days']=pd.to_numeric(df['delivery_days'],errors='coerce')
df['delivery_days']
# Out:
# 0      5.0
# 1      5.0
# 2      7.0
# 3      3.0
# 4      3.0
#       ...
# 995    1.0
# 996    2.0
# 997    1.0
# 998    2.0
# 999   -1.0
# Name: delivery_days, Length: 1000, dtype: float64

# %%
import numpy as np
df['delivery_days']=pd.to_numeric(df['delivery_days'], errors='coerce')
df.loc[df['delivery_days']<0, 'delivery_days'] = np.nan
df['delivery_days']
# Out:
# 0      5.0
# 1      5.0
# 2      7.0
# 3      3.0
# 4      3.0
#       ...
# 995    1.0
# 996    2.0
# 997    1.0
# 998    2.0
# 999    NaN
# Name: delivery_days, Length: 1000, dtype: float64

# %% [markdown]
# ## TASK 3 ---> Standardize payment mode and calulate the percentage share of each mode per city.

# %%
payment=pd.value_counts(df['payment_mode'])
payment
# Out:
# C:\Users\N.SAI VAIBHAV\AppData\Local\Temp\ipykernel_21396\3312840693.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   payment=pd.value_counts(df['payment_mode'])
# payment_mode
# Cash           158
# UPI            157
# CARD           151
# Debit Card     141
# upi            135
# Credit Card    123
# Name: count, dtype: int64

# %%
cityy=pd.value_counts(df['city'])
cityy
# Out:
# C:\Users\N.SAI VAIBHAV\AppData\Local\Temp\ipykernel_21396\627616947.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   cityy=pd.value_counts(df['city'])
# city
# Delhi        161
# Bangalore    151
# Mumbai       145
# DELHI        141
# Hyderabad    141
# mumbai       119
# Name: count, dtype: int64

# %%
df
# Out:
#     order_id customer_id  customer_age order_amount order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5 2023-01-15   Debit Card
# 1    ORD1001         NaN          18.0         1200        NaT   Debit Card
# 2    ORD1002       CUST2          35.0          NaN        NaT          NaN
# 3    ORD1003      user_3          35.0         1200 2023-01-15         Cash
# 4    ORD1004      user_4          -3.0      3500.75 2023-01-15         CARD
# ..       ...         ...           ...          ...        ...          ...
# 995      NaN    user_995          -3.0      3500.75        NaT          upi
# 996      NaN     CUST996          18.0          NaN 2023-01-15  Credit Card
# 997      NaN    user_997          50.0          NaN        NaT         Cash
# 998  ORD1998         NaN          65.0         1200 2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN        NaT   Debit Card
#
#           city  delivery_days is_delivered
# ...

# %%
df['payment_mode']=(df['payment_mode']).str.strip().str.lower()
df['payment_mode']
# Out:
# 0       debit card
# 1       debit card
# 2              NaN
# 3             cash
# 4             card
#           ...
# 995            upi
# 996    credit card
# 997           cash
# 998            NaN
# 999     debit card
# Name: payment_mode, Length: 1000, dtype: object

# %%
df['city']=(df['city']).str.strip().str.lower()

# %%
# df['percentage']=(df.groupby('city')['payment_mode'].value_counts(normalize=True)*100)

share = df.groupby(['city', 'payment_mode']).size()
percentage = share / share.groupby(level=0).sum() * 100

# %%
percentage_df=pd.DataFrame(percentage,columns=['percentage']).reset_index()
percentage_df
# Out:
#          city payment_mode  percentage
# 0   bangalore         card   19.531250
# 1   bangalore         cash   17.187500
# 2   bangalore  credit card   11.718750
# 3   bangalore   debit card   18.750000
# 4   bangalore          upi   32.812500
# 5       delhi         card   17.582418
# 6       delhi         cash   16.849817
# 7       delhi  credit card   15.018315
# 8       delhi   debit card   17.948718
# 9       delhi          upi   32.600733
# 10  hyderabad         card   19.658120
# 11  hyderabad         cash   17.094017
# 12  hyderabad  credit card   15.384615
# 13  hyderabad   debit card   17.094017
# 14  hyderabad          upi   30.769231
# 15     mumbai         card   13.839286
# 16     mumbai         cash   19.642857
# 17     mumbai  credit card   14.285714
# 18     mumbai   debit card   16.071429
# 19     mumbai          upi   36.160714

# %% [markdown]
# ## TASK 4 -->Detect customers whose  customer_age is invalid but have order amounts above the median

# %%
df
# Out:
#     order_id customer_id  customer_age order_amount order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5 2023-01-15   debit card
# 1    ORD1001         NaN          18.0         1200        NaT   debit card
# 2    ORD1002       CUST2          35.0          NaN        NaT          NaN
# 3    ORD1003      user_3          35.0         1200 2023-01-15         cash
# 4    ORD1004      user_4          -3.0      3500.75 2023-01-15         card
# ..       ...         ...           ...          ...        ...          ...
# 995      NaN    user_995          -3.0      3500.75        NaT          upi
# 996      NaN     CUST996          18.0          NaN 2023-01-15  credit card
# 997      NaN    user_997          50.0          NaN        NaT         cash
# 998  ORD1998         NaN          65.0         1200 2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN        NaT   debit card
#
#           city  delivery_days is_delivered
# ...

# %%
df['customer_age']=pd.to_numeric(df['customer_age'],errors='coerce')
df['customer_age']
# Out:
# 0        NaN
# 1       18.0
# 2       35.0
# 3       35.0
# 4       -3.0
#        ...
# 995     -3.0
# 996     18.0
# 997     50.0
# 998     65.0
# 999    120.0
# Name: customer_age, Length: 1000, dtype: float64

# %%
df[((df['customer_age']<0) | (df['customer_age'].isna())) ]
# Out:
#     order_id customer_id  customer_age order_amount order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5 2023-01-15   debit card
# 4    ORD1004      user_4          -3.0      3500.75 2023-01-15         card
# 5        NaN         NaN           NaN         1200 2023-01-15         card
# 6    ORD1006       CUST6          -3.0          NaN        NaT          upi
# 9        NaN      user_9           NaN          NaN        NaT          upi
# ..       ...         ...           ...          ...        ...          ...
# 989  ORD1989         NaN           NaN         1200 2023-01-15          upi
# 991      NaN         NaN          -3.0      3500.75        NaT         card
# 992      NaN     CUST992           NaN          NaN 2023-01-15         card
# 994      NaN         NaN           NaN        250.5        NaT   debit card
# 995      NaN    user_995          -3.0      3500.75        NaT          upi
#
#           city  delivery_days is_delivered
# ...

# %%
df['order_amount']=pd.to_numeric(df['order_amount'],errors='coerce')
med=df['order_amount'].median()
data=df[(df['customer_age'].isna()) & (df ['order_amount']>med)]
data
# Out:
#     order_id customer_id  customer_age  order_amount order_date payment_mode  \
# 5        NaN         NaN           NaN       1200.00 2023-01-15         card
# 37       NaN         NaN           NaN       3500.75        NaT         card
# 44   ORD1044         NaN           NaN       3500.75        NaT          upi
# 75       NaN      CUST75           NaN       1200.00        NaT          upi
# 76       NaN         NaN           NaN       3500.75        NaT          NaN
# ..       ...         ...           ...           ...        ...          ...
# 895  ORD1895    user_895           NaN       1200.00        NaT   debit card
# 902      NaN    user_902           NaN       1200.00        NaT          upi
# 924      NaN         NaN           NaN       3500.75 2023-01-15         card
# 930  ORD1930         NaN           NaN       1200.00        NaT          NaN
# 989  ORD1989         NaN           NaN       1200.00 2023-01-15          upi
#
#           city  delivery_days is_delivered
# ...

# %% [markdown]
# ## TASK 5 --> Find duplicate customer_ids where the same customer placed orders in multiple cities.

# %%
## TASK 5 --> Find duplicate customer_ids where the same customer placed orders in multiple cities.
unique_city=df.groupby('customer_id')['city'].nunique()
cust_order=unique_city[unique_city>=1].reset_index()
cust_order
# Out:
#     customer_id  city
# 0       CUST108     1
# 1        CUST11     1
# 2       CUST111     1
# 3       CUST117     1
# 4       CUST119     1
# ..          ...   ...
# 408    user_959     1
# 409     user_97     1
# 410    user_977     1
# 411    user_995     1
# 412    user_997     1
#
# [413 rows x 2 columns]

# %% [markdown]
# ## TASK 6 ---> Create a flag for orders where delivery_days is missing but is_delivered is True.

# %%
df
# Out:
#     order_id customer_id  customer_age  order_amount order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.50 2023-01-15   debit card
# 1    ORD1001         NaN          18.0       1200.00        NaT   debit card
# 2    ORD1002       CUST2          35.0           NaN        NaT          NaN
# 3    ORD1003      user_3          35.0       1200.00 2023-01-15         cash
# 4    ORD1004      user_4          -3.0       3500.75 2023-01-15         card
# ..       ...         ...           ...           ...        ...          ...
# 995      NaN    user_995          -3.0       3500.75        NaT          upi
# 996      NaN     CUST996          18.0           NaN 2023-01-15  credit card
# 997      NaN    user_997          50.0           NaN        NaT         cash
# 998  ORD1998         NaN          65.0       1200.00 2023-01-15          NaN
# 999      NaN    user_999         120.0           NaN        NaT   debit card
#
#           city  delivery_days is_delivered
# ...

# %%
result = df[(df['delivery_days'].isna()) & (df['is_delivered'].isin(['True', 'yes']))]
result
# df[result].value_counts()
# Out:
#     order_id customer_id  customer_age  order_amount order_date payment_mode  \
# 17       NaN         NaN          -3.0           NaN        NaT          upi
# 21       NaN         NaN          25.0        499.99        NaT  credit card
# 27       NaN         NaN          25.0           NaN 2023-01-15          NaN
# 33   ORD1033     user_33         120.0        499.99        NaT          upi
# 35       NaN     user_35          50.0        499.99        NaT         cash
# ..       ...         ...           ...           ...        ...          ...
# 967      NaN         NaN          65.0           NaN        NaT          NaN
# 979      NaN         NaN          18.0       1200.00        NaT          NaN
# 980      NaN     CUST980           NaN        250.50        NaT         cash
# 987      NaN     CUST987          50.0           NaN        NaT          NaN
# 999      NaN    user_999         120.0           NaN        NaT   debit card
#
#           city  delivery_days is_delivered
# ...

# %% [markdown]
# ## TASK-7

# %%
# compute the average order amount per each payment mode excluding invalid amounts

k=df.groupby('payment_mode')['order_amount'].mean()
gg=k.reset_index(name='average_order')
gg
# Out:
#   payment_mode  average_order
# 0         card    1553.016237
# 1         cash    1414.393708
# 2  credit card    1243.262656
# 3   debit card    1432.739318
# 4          upi    1349.349091

# %%
# identify cities with missing order dates
missing_order_dates = df[df['order_date'].isna()]['city'].unique()
missing_order_dates [ missing_order_dates > 30]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 3
#       1 # identify cities with missing order dates
#       2 missing_order_dates = df[df['order_date'].isna()]['city'].unique()
# ----> 3 missing_order_dates [ missing_order_dates > 30]
#
# TypeError: '>' not supported between instances of 'str' and 'int'
