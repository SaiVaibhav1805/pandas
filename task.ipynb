# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## IMPORTING THE FILE

# %%
task=pd.read_csv('task.csv')
task
# Out:
#       user_id      age     salary department   join_date       city  \
# 0      user_0       -5     ₹50000         HR  2020/12/01      DELHI
# 1       U1001       30      45000    Finance  15/02/2021      Delhi
# 2       U1002       30      25000         HR         NaN      Delhi
# 3         NaN  unknown        NaN         HR     invalid  Hyderabad
# 4         NaN      NaN  120000.75         IT         NaN      DELHI
# ..        ...      ...        ...        ...         ...        ...
# 995       NaN       60     ₹50000         HR  15/02/2021      DELHI
# 996     U1996      NaN        NaN         IT  15/02/2021     Mumbai
# 997  user_997  unknown      25000         HR     invalid     Mumbai
# 998     U1998       -5      25000        NaN  15/02/2021  Bangalore
# 999       NaN       30      45000         HR  2022-01-15  Hyderabad
#
#     performance_score experience_years is_active
# 0                   3             five      True
# 1                   3                1       yes
# ...

# %% [markdown]
# ## HEAD  COLUMNS AND DATA

# %%
task.head()
task.columns
task.dtypes
# Out:
# user_id              object
# age                  object
# salary               object
# department           object
# join_date            object
# city                 object
# performance_score    object
# experience_years     object
# is_active            object
# dtype: object

# %% [markdown]
# ## TASK-2

# %%
(task.isna().sum())*100/len(task)
# Out:
# user_id              51.0
# age                  11.4
# salary               31.1
# department           14.1
# join_date            21.9
# city                 14.9
# performance_score    10.1
# experience_years     12.7
# is_active            20.0
# dtype: float64

# %% [markdown]
# ## TASK-3

# %%
task.apply(lambda x: x.map(type).nunique())
# Out:
# user_id              2
# age                  2
# salary               2
# department           2
# join_date            2
# city                 2
# performance_score    2
# experience_years     2
# is_active            2
# dtype: int64

# %% [markdown]
# ## TASK-4

# %%
#cleaning user_id by replacing empty strings with Nan and converting the column to uppercase
task['user_id']=task['user_id'].replace('',np.nan).str.upper()
task['user_id']
# Out:
# 0        USER_0
# 1         U1001
# 2         U1002
# 3           NaN
# 4           NaN
#          ...
# 995         NaN
# 996       U1996
# 997    USER_997
# 998       U1998
# 999         NaN
# Name: user_id, Length: 1000, dtype: object

# %% [markdown]
# ## TASK-5

# %%
task['age']=pd.to_numeric(task['age'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "unknown"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 task['age']=pd.to_numeric(task['age'])
#
# File c:\Users\N.SAI VAIBHAV\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
# ...

# %%
task['join_date']=pd.to_datetime(task['join_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 task['join_date']=pd.to_datetime(task['join_date'])
#
# File c:\Users\N.SAI VAIBHAV\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File c:\Users\N.SAI VAIBHAV\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# ...
